# %%
from utils import virtuoso_running as vr
from classes.Style import relax, sad
# Out:
# /Users/batman/git/piano-style/utils/virtuoso_running.py:517: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i is not 0:

# %%
MODEL_TYPE = "isgn"
TRILL_MODEL = 'trill_default'
PATH = "test_pieces/emotionNet/Bach_Prelude_1/"
COMPOSER_NAME = "Bach"
DATA_FILE = "training_data"

# %%
mix = relax.approach(sad, 0.5, 'Sad_Relax_Mix')
overcorrection = relax.approach(sad, 1.2, 'Overcorrection')

latent = relax.to_dict()

# %%
model = vr.load_model(MODEL_TYPE)
trill_model = vr.load_model(TRILL_MODEL)

# %%
means, stds, bins, _, _, _, _ = vr.load_stat_file(DATA_FILE)

# %%
vr.load_file_and_generate_performance(PATH, COMPOSER_NAME, latent, means, stds, bins, model, MODEL_TYPE, trill_model)
# Out:
# /Users/batman/git/piano-style/venv/lib/python3.8/site-packages/torch/nn/functional.py:1794: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# ...
